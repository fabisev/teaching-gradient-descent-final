# %% [markdown]
# # Results
#
# This project version contains the teaching material for the gradient-descent comparison, not empirical study results. The shared assessment material is in [Common Questions for Both Conditions](06-transfer-and-exercises/06-transfer-and-exercises.md), and the active interactive material is in [Interactive Exploration](05-interactive-exploration/05-interactive-exploration.md).
